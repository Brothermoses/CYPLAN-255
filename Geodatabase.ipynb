# %%
import geopandas
import matplotlib.pyplot as plt

gdf = geopandas.read_file("Census_Tract_Boundaries_7506545346012929933.geojson")

gdf.plot()
gdf.head()
# Out:
#    OBJECTID           DIST_NAME  DISTRICT_ID  \
# 0         1  CENSUS TRACT #4001          184
# 1         2  CENSUS TRACT #4002          185
# 2         3  CENSUS TRACT #4003          186
# 3         4  CENSUS TRACT #4004          187
# 4         5  CENSUS TRACT #4005          188
#
#                                             geometry
# 0  POLYGON ((-122.24466 37.88364, -122.24256 37.8...
# 1  POLYGON ((-122.24478 37.85173, -122.24471 37.8...
# 2  POLYGON ((-122.24939 37.83924, -122.25011 37.8...
# 3  POLYGON ((-122.25313 37.85154, -122.25307 37.8...
# 4  POLYGON ((-122.26017 37.85262, -122.26025 37.8...
